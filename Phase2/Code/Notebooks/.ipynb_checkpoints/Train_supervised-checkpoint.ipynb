# %%
import cv2
import sys
import os
import glob
import random
from skimage import data, exposure, img_as_float
import matplotlib.pyplot as plt
from Misc.MiscUtils import *
from Misc.DataUtils import *
import numpy as np
import time
import argparse
import shutil
from io import StringIO
import string
from termcolor import colored, cprint
import math as m
from tqdm import tqdm
import csv
from sklearn.preprocessing import StandardScaler
# Don't generate pyc codes
sys.dont_write_bytecode = True

import tensorflow as tf

from keras import backend as K

from keras.utils import Sequence
from keras.initializers import VarianceScaling
from keras.models import Sequential
from keras.layers import  Activation, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization, InputLayer
from keras import optimizers
from keras.callbacks import ModelCheckpoint

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

# %%
# Out:
# (999, 128, 128, 2)

# %%
class loadDataBatches_gen(Sequence):
    def __init__(self,base_path, files_in_dir, labels_in_dir, batch_size, shuffle=True):
        
        self.labels_in_dir = labels_in_dir
        self.files_in_dir  = files_in_dir
        self.base_path = base_path
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.files_in_dir))
#         self.indexes = np.arange(128)

    def __len__(self):
        # returns the number of batches
        return len(files_in_dir) // self.batch_size

    def __getitem__(self, index):
        # returns one batch
        indices = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        X, y = self.__dataGen(indices)

        return X, y
    
    def on_epoch_end(self):
        'Updates indexes after each epoch'
#         self.indexes = np.arange(len(self.files_in_dir))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)    
    

    def __dataGen(self, indices):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        images_batch = []
        labels_batch = []
        for i in indices:

            #Get one row of x,Y
            image1_name = self.base_path + os.sep + "Train_synthetic/PA/" + self.files_in_dir[i, 0]
            image1 = cv2.imread(image1_name)[:,:,0]
#             image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

            image2_name = self.base_path + os.sep + "Train_synthetic/PB/" + self.files_in_dir[i, 0] 
            image2 = cv2.imread(image2_name)[:,:,0]
#             image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

            if(image1 is None) or (image2 is None):
                continue
                
#             image1 = cv2.normalize(image1.astype(np.float32), None, 0.0, 1.0, cv2.NORM_MINMAX)
#             image2 = cv2.normalize(image2.astype(np.float32), None, 0.0, 1.0, cv2.NORM_MINMAX)

            image = np.dstack((image1.astype(np.float32), image2.astype(np.float32)))

            images_batch.append(image)
            labels_batch.append(labels_in_dir[i,:])

        return np.array(images_batch), np.array(labels_batch) 
        
    
print("################################################ DataGenerator defined")

def HomographyNet():

#     hidden_layer_size, num_classes = 1000, 8
    input_shape = (128, 128, 2)
    kernel_size = 3
    pool_size = 2
    filters = 64
    dropout = 0.5

    kernel_initializer = VarianceScaling(scale=2.0)
    
    model = Sequential()
    model.add(InputLayer(input_shape))
    ## conv2d 128
    model.add(Conv2D(filters=filters,kernel_size = kernel_size, activation ='relu', padding ='same'))
    model.add(BatchNormalization())
    
    ## conv2d 128
    model.add(Conv2D(filters = filters,kernel_size = kernel_size, activation = 'relu', padding = 'same'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size))
    
    ## conv2d 64
    model.add(Conv2D(filters=filters,kernel_size=kernel_size, activation = 'relu', padding = 'same'))
    model.add(BatchNormalization())
    ## conv2d 64
    model.add(Conv2D(filters=filters, kernel_size=kernel_size, activation='relu', padding='same'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size))
    
    ## conv2d 32 2x Filters
    model.add(Conv2D(filters=filters*2,kernel_size=kernel_size, activation='relu', padding='same',))
    model.add(BatchNormalization())
    ## conv2d 32 2x Filters
    model.add(Conv2D(filters=filters*2,kernel_size=kernel_size, activation='relu', padding='same',))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size))
    
    ## conv2d 16 2x Filters
    model.add(Conv2D(filters=filters*2, kernel_size=kernel_size, activation='relu', padding='same',))
    model.add(BatchNormalization())
    ## conv2d 16 2x Filters
    model.add(Conv2D(filters=filters*2, kernel_size=kernel_size, activation='relu', padding='same',))
    model.add(BatchNormalization())
    
    model.add(Flatten())
    model.add(Dropout(dropout))
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(dropout))
    #for regression model
    model.add(Dense(8))
    return model

#Loss Function using SMSE
def L2_loss(y_true, y_pred):
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1, keepdims=True))

# %% [markdown]
# # Initialise Model and Run

# %%
#Loss Function using SMSE

model = HomographyNet()
Adam = optimizers.AdamOptimizer(lr=0.0005)

model.compile(loss= euclidean_l2, optimizer=Adam, metrics=['mean_absolute_error'])
# model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 2)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      1216
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              33555456
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 8200
# =================================================================
# Total params: 34,195,336
# Trainable params: 34,193,800
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
base_path = "/home/gokul/CMSC733/hgokul_p1/Phase2/Data"
CheckPointPath = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised/"
files_in_dir, SaveCheckPoint, ImageSize, NumTrainSamples, labels_in_dir = SetupAll(base_path, CheckPointPath,True)

ckptPath = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-{epoch:02d}-{loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(ckptPath, monitor='loss', verbose=1)
                             
epochs = 50
number_of_training_samples = 4985
batch_size = 64
num_terations_per_epoch = int(number_of_training_samples / batch_size)

# %%
generator = loadDataBatches_gen(base_path, files_in_dir, labels_in_dir, batch_size, True)
print('TRAINING...')                             
model.fit_generator(generator = generator,steps_per_epoch = num_terations_per_epoch,  epochs = epochs, callbacks=[checkpoint])
# Out:
# TRAINING...
# Epoch 1/50
# Batch Count:  49
# Batch Count:  20
# Batch Count:  63
# Batch Count:  59
# Batch Count:  22
# Batch Count:  30
# Batch Count:  16
# Batch Count:  43
# Batch Count:  1
# Batch Count:  27
# Batch Count:  58
# Batch Count:  14
#  1/77 [..............................] - ETA: 211s - loss: 48.8005 - mean_squared_error: 303.5453Batch Count:  4
#  2/77 [..............................] - ETA: 115s - loss: 48.7244 - mean_squared_error: 303.7551Batch Count:  13
#  3/77 [>.............................] - ETA: 82s - loss: 48.4859 - mean_squared_error: 301.2286 Batch Count:  61
#  4/77 [>.............................] - ETA: 66s - loss: 48.3624 - mean_squared_error: 300.5329Batch Count:  28
#  5/77 [>.............................] - ETA: 56s - loss: 48.8271 - mean_squared_error: 306.1913Batch Count:  42
#  6/77 [=>............................] - ETA: 49s - loss: 48.7828 - mean_squared_error: 305.9602Batch Count:  67
#  7/77 [=>............................] - ETA: 44s - loss: 48.6629 - mean_squared_error: 304.5401Batch Count:  64
#  8/77 [==>...........................] - ETA: 40s - loss: 48.8661 - mean_squared_error: 307.3208Batch Count:  71
#  9/77 [==>...........................] - ETA: 37s - loss: 48.7619 - mean_squared_error: 306.1203Batch Count:  10
# 10/77 [==>...........................] - ETA: 35s - loss: 48.7087 - mean_squared_error: 305.5047Batch Count:  51
# 11/77 [===>..........................] - ETA: 33s - loss: 48.8297 - mean_squared_error: 306.9122Batch Count:  18
# 12/77 [===>..........................] - ETA: 31s - loss: 48.8529 - mean_squared_error: 307.3246Batch Count:  35
# 13/77 [====>.........................] - ETA: 30s - loss: 48.7821 - mean_squared_error: 306.3370Batch Count:  41
# 14/77 [====>.........................] - ETA: 28s - loss: 48.7980 - mean_squared_error: 306.6135Batch Count:  40
# 15/77 [====>.........................] - ETA: 27s - loss: 48.6956 - mean_squared_error: 305.4183Batch Count:  69
# 16/77 [=====>........................] - ETA: 26s - loss: 48.8590 - mean_squared_error: 307.3437Batch Count:  33
# 17/77 [=====>........................] - ETA: 25s - loss: 48.9001 - mean_squared_error: 307.8795Batch Count:  47
# 18/77 [======>.......................] - ETA: 24s - loss: 48.9874 - mean_squared_error: 308.9062Batch Count:  53
# 19/77 [======>.......................] - ETA: 23s - loss: 49.0095 - mean_squared_error: 309.1045Batch Count:  7
# 20/77 [======>.......................] - ETA: 23s - loss: 49.0277 - mean_squared_error: 309.3431Batch Count:  5
# 21/77 [=======>......................] - ETA: 22s - loss: 49.0688 - mean_squared_error: 309.9133Batch Count:  54
# 22/77 [=======>......................] - ETA: 21s - loss: 49.0584 - mean_squared_error: 309.9246Batch Count:  62
# 23/77 [=======>......................] - ETA: 20s - loss: 49.0313 - mean_squared_error: 309.6727Batch Count:  50
# 24/77 [========>.....................] - ETA: 20s - loss: 49.0195 - mean_squared_error: 309.5629Batch Count:  73
# 25/77 [========>.....................] - ETA: 19s - loss: 49.0485 - mean_squared_error: 310.1260Batch Count:  29
# 26/77 [=========>....................] - ETA: 19s - loss: 49.1277 - mean_squared_error: 311.1298Batch Count:  15
# 27/77 [=========>....................] - ETA: 18s - loss: 49.1412 - mean_squared_error: 311.2256Batch Count:  65
# 28/77 [=========>....................] - ETA: 18s - loss: 49.2085 - mean_squared_error: 312.0906Batch Count:  23
# 29/77 [==========>...................] - ETA: 17s - loss: 49.2583 - mean_squared_error: 312.7430Batch Count:  68
# 30/77 [==========>...................] - ETA: 17s - loss: 49.2844 - mean_squared_error: 313.1744Batch Count:  31
# 31/77 [===========>..................] - ETA: 16s - loss: 49.3184 - mean_squared_error: 313.5617Batch Count:  6
# 32/77 [===========>..................] - ETA: 16s - loss: 49.3218 - mean_squared_error: 313.6329Batch Count:  26
# 33/77 [===========>..................] - ETA: 15s - loss: 49.3183 - mean_squared_error: 313.6754Batch Count:  48
# 34/77 [============>.................] - ETA: 15s - loss: 49.3586 - mean_squared_error: 314.2909Batch Count:  45
# 35/77 [============>.................] - ETA: 14s - loss: 49.4519 - mean_squared_error: 315.4401Batch Count:  19
# 36/77 [=============>................] - ETA: 14s - loss: 49.4809 - mean_squared_error: 315.8881Batch Count:  56
# 37/77 [=============>................] - ETA: 13s - loss: 49.5356 - mean_squared_error: 316.6813Batch Count:  44
# 38/77 [=============>................] - ETA: 13s - loss: 49.5366 - mean_squared_error: 316.7530Batch Count:  57
# 39/77 [==============>...............] - ETA: 13s - loss: 49.6154 - mean_squared_error: 317.7562Batch Count:  75
# 40/77 [==============>...............] - ETA: 12s - loss: 49.6194 - mean_squared_error: 317.7972Batch Count:  38
# 41/77 [==============>...............] - ETA: 12s - loss: 49.6358 - mean_squared_error: 318.0434Batch Count:  24
# 42/77 [===============>..............] - ETA: 11s - loss: 49.6382 - mean_squared_error: 318.1027Batch Count:  36
# 43/77 [===============>..............] - ETA: 11s - loss: 49.6414 - mean_squared_error: 318.2119Batch Count:  70
# 44/77 [================>.............] - ETA: 11s - loss: 49.6336 - mean_squared_error: 318.0679Batch Count:  66
# 45/77 [================>.............] - ETA: 10s - loss: 49.6728 - mean_squared_error: 318.6568Batch Count:  37
# 46/77 [================>.............] - ETA: 10s - loss: 49.6433 - mean_squared_error: 318.3987Batch Count:  3
# 47/77 [=================>............] - ETA: 10s - loss: 49.6065 - mean_squared_error: 318.0377Batch Count:  52
# 48/77 [=================>............] - ETA: 9s - loss: 49.5981 - mean_squared_error: 317.9467 Batch Count:  32
# 49/77 [==================>...........] - ETA: 9s - loss: 49.5509 - mean_squared_error: 317.3658Batch Count:  0
# 50/77 [==================>...........] - ETA: 8s - loss: 49.5287 - mean_squared_error: 317.0975Batch Count:  8
# 51/77 [==================>...........] - ETA: 8s - loss: 49.5475 - mean_squared_error: 317.3159Batch Count:  12
# 52/77 [===================>..........] - ETA: 8s - loss: 49.5553 - mean_squared_error: 317.4073Batch Count:  46
# 53/77 [===================>..........] - ETA: 7s - loss: 49.5205 - mean_squared_error: 316.9484Batch Count:  34
# 54/77 [====================>.........] - ETA: 7s - loss: 49.5018 - mean_squared_error: 316.7423Batch Count:  72
# 55/77 [====================>.........] - ETA: 7s - loss: 49.4541 - mean_squared_error: 316.2156Batch Count:  74
# 56/77 [====================>.........] - ETA: 6s - loss: 49.4713 - mean_squared_error: 316.4296Batch Count:  39
# 57/77 [=====================>........] - ETA: 6s - loss: 49.4281 - mean_squared_error: 315.8784Batch Count:  2
# 58/77 [=====================>........] - ETA: 6s - loss: 49.3833 - mean_squared_error: 315.4017Batch Count:  76
# 59/77 [=====================>........] - ETA: 5s - loss: 49.3346 - mean_squared_error: 314.8373Batch Count:  55
# 60/77 [======================>.......] - ETA: 5s - loss: 49.3180 - mean_squared_error: 314.6926Batch Count:  9
# 61/77 [======================>.......] - ETA: 5s - loss: 49.2832 - mean_squared_error: 314.2844Batch Count:  17
# 62/77 [=======================>......] - ETA: 4s - loss: 49.2260 - mean_squared_error: 313.6346Batch Count:  21
# 63/77 [=======================>......] - ETA: 4s - loss: 49.1820 - mean_squared_error: 313.1162Batch Count:  11
# 64/77 [=======================>......] - ETA: 4s - loss: 49.1474 - mean_squared_error: 312.6626Batch Count:  25
# 65/77 [========================>.....] - ETA: 3s - loss: 49.1128 - mean_squared_error: 312.2259Batch Count:  60
# 66/77 [========================>.....] - ETA: 3s - loss: 49.0512 - mean_squared_error: 311.5422Batch Count:  70
# 67/77 [=========================>....] - ETA: 3s - loss: 49.0326 - mean_squared_error: 311.3171Batch Count:  28
# 68/77 [=========================>....] - ETA: 2s - loss: 48.9921 - mean_squared_error: 310.8366Batch Count:  23
# 69/77 [=========================>....] - ETA: 2s - loss: 48.9425 - mean_squared_error: 310.2382Batch Count:  32
# 70/77 [==========================>...] - ETA: 2s - loss: 48.8946 - mean_squared_error: 309.6723Batch Count:  42
# 71/77 [==========================>...] - ETA: 1s - loss: 48.8482 - mean_squared_error: 309.0965Batch Count:  57
# 72/77 [===========================>..] - ETA: 1s - loss: 48.8211 - mean_squared_error: 308.7553Batch Count:  17
# 73/77 [===========================>..] - ETA: 1s - loss: 48.7889 - mean_squared_error: 308.3767Batch Count:  65
# 74/77 [===========================>..] - ETA: 0s - loss: 48.7558 - mean_squared_error: 308.0409Batch Count:  59
# 75/77 [============================>.] - ETA: 0s - loss: 48.7252 - mean_squared_error: 307.6819Batch Count:  69
# 76/77 [============================>.] - ETA: 0s - loss: 48.6691 - mean_squared_error: 307.0598Batch Count:  53
# Epoch 00000: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-00-48.64.hdf5
# 77/77 [==============================] - 25s - loss: 48.6437 - mean_squared_error: 306.8168
# Epoch 2/50
# Batch Count:  58
#  1/77 [..............................] - ETA: 21s - loss: 44.6299 - mean_squared_error: 259.0177Batch Count:  33
#  2/77 [..............................] - ETA: 21s - loss: 44.1559 - mean_squared_error: 254.5443Batch Count:  37
#  3/77 [>.............................] - ETA: 21s - loss: 44.0883 - mean_squared_error: 254.0429Batch Count:  39
#  4/77 [>.............................] - ETA: 20s - loss: 44.5066 - mean_squared_error: 259.1437Batch Count:  10
#  5/77 [>.............................] - ETA: 20s - loss: 44.3242 - mean_squared_error: 256.7017Batch Count:  26
#  6/77 [=>............................] - ETA: 20s - loss: 44.3516 - mean_squared_error: 257.3343Batch Count:  49
#  7/77 [=>............................] - ETA: 19s - loss: 44.5315 - mean_squared_error: 259.2379Batch Count:  12
#  8/77 [==>...........................] - ETA: 19s - loss: 44.8218 - mean_squared_error: 262.9929Batch Count:  64
#  9/77 [==>...........................] - ETA: 19s - loss: 44.8777 - mean_squared_error: 263.8675Batch Count:  15
# 10/77 [==>...........................] - ETA: 19s - loss: 45.0251 - mean_squared_error: 265.4145Batch Count:  52
# 11/77 [===>..........................] - ETA: 18s - loss: 44.9828 - mean_squared_error: 264.6509Batch Count:  2
# 12/77 [===>..........................] - ETA: 18s - loss: 45.0338 - mean_squared_error: 265.2411Batch Count:  6
# 13/77 [====>.........................] - ETA: 18s - loss: 45.1021 - mean_squared_error: 265.8667Batch Count:  54
# 14/77 [====>.........................] - ETA: 17s - loss: 45.0329 - mean_squared_error: 265.2374Batch Count:  48
# 15/77 [====>.........................] - ETA: 17s - loss: 44.9845 - mean_squared_error: 264.7056Batch Count:  40
# 16/77 [=====>........................] - ETA: 17s - loss: 44.8332 - mean_squared_error: 263.0745Batch Count:  62
# 17/77 [=====>........................] - ETA: 17s - loss: 44.8542 - mean_squared_error: 263.4649Batch Count:  20
# 18/77 [======>.......................] - ETA: 16s - loss: 44.8699 - mean_squared_error: 263.6339Batch Count:  46
# 19/77 [======>.......................] - ETA: 16s - loss: 44.7585 - mean_squared_error: 262.3831Batch Count:  4
# 20/77 [======>.......................] - ETA: 16s - loss: 44.8125 - mean_squared_error: 262.9038Batch Count:  68
# 21/77 [=======>......................] - ETA: 15s - loss: 44.7222 - mean_squared_error: 261.8663Batch Count:  21
# 22/77 [=======>......................] - ETA: 15s - loss: 44.6442 - mean_squared_error: 261.3185Batch Count:  60
# 23/77 [=======>......................] - ETA: 15s - loss: 44.7418 - mean_squared_error: 262.3851Batch Count:  75
# 24/77 [========>.....................] - ETA: 15s - loss: 44.7868 - mean_squared_error: 262.9331Batch Count:  9
# 25/77 [========>.....................] - ETA: 14s - loss: 44.7280 - mean_squared_error: 262.3429Batch Count:  35
# 26/77 [=========>....................] - ETA: 14s - loss: 44.7242 - mean_squared_error: 262.3241Batch Count:  71
# 27/77 [=========>....................] - ETA: 14s - loss: 44.6834 - mean_squared_error: 261.8735Batch Count:  18
# 28/77 [=========>....................] - ETA: 13s - loss: 44.6183 - mean_squared_error: 261.1485Batch Count:  43
# 29/77 [==========>...................] - ETA: 13s - loss: 44.6066 - mean_squared_error: 260.9505Batch Count:  8
# 30/77 [==========>...................] - ETA: 13s - loss: 44.6803 - mean_squared_error: 261.9394Batch Count:  36
# 31/77 [===========>..................] - ETA: 13s - loss: 44.6207 - mean_squared_error: 261.3476Batch Count:  27
# 32/77 [===========>..................] - ETA: 12s - loss: 44.6000 - mean_squared_error: 261.0578Batch Count:  5
# 33/77 [===========>..................] - ETA: 12s - loss: 44.6169 - mean_squared_error: 261.2365Batch Count:  51
# 34/77 [============>.................] - ETA: 12s - loss: 44.5560 - mean_squared_error: 260.5772Batch Count:  73
# 35/77 [============>.................] - ETA: 11s - loss: 44.5449 - mean_squared_error: 260.4281Batch Count:  74
# 36/77 [=============>................] - ETA: 11s - loss: 44.5155 - mean_squared_error: 260.0805Batch Count:  41
# 37/77 [=============>................] - ETA: 11s - loss: 44.4940 - mean_squared_error: 259.8538Batch Count:  66
# 38/77 [=============>................] - ETA: 11s - loss: 44.5442 - mean_squared_error: 260.4000Batch Count:  7
# 39/77 [==============>...............] - ETA: 10s - loss: 44.5118 - mean_squared_error: 260.1400Batch Count:  0
# 40/77 [==============>...............] - ETA: 10s - loss: 44.5598 - mean_squared_error: 260.6719Batch Count:  19
# 41/77 [==============>...............] - ETA: 10s - loss: 44.5290 - mean_squared_error: 260.2243Batch Count:  44
# 42/77 [===============>..............] - ETA: 9s - loss: 44.5605 - mean_squared_error: 260.5700 Batch Count:  76
# 43/77 [===============>..............] - ETA: 9s - loss: 44.6064 - mean_squared_error: 261.1363Batch Count:  31
# 44/77 [================>.............] - ETA: 9s - loss: 44.5978 - mean_squared_error: 261.1140Batch Count:  14
# 45/77 [================>.............] - ETA: 9s - loss: 44.5441 - mean_squared_error: 260.5521Batch Count:  67
# 46/77 [================>.............] - ETA: 8s - loss: 44.5460 - mean_squared_error: 260.6161Batch Count:  29
# 47/77 [=================>............] - ETA: 8s - loss: 44.5275 - mean_squared_error: 260.4474Batch Count:  13
# 48/77 [=================>............] - ETA: 8s - loss: 44.5106 - mean_squared_error: 260.2187Batch Count:  50
# 49/77 [==================>...........] - ETA: 7s - loss: 44.4785 - mean_squared_error: 259.8458Batch Count:  47
# 50/77 [==================>...........] - ETA: 7s - loss: 44.4515 - mean_squared_error: 259.5692Batch Count:  72
# 51/77 [==================>...........] - ETA: 7s - loss: 44.4309 - mean_squared_error: 259.2922Batch Count:  1
# 52/77 [===================>..........] - ETA: 7s - loss: 44.3828 - mean_squared_error: 258.7872Batch Count:  11
# 53/77 [===================>..........] - ETA: 6s - loss: 44.3250 - mean_squared_error: 258.1029Batch Count:  38
# 54/77 [====================>.........] - ETA: 6s - loss: 44.3121 - mean_squared_error: 257.9693Batch Count:  16
# 55/77 [====================>.........] - ETA: 6s - loss: 44.3156 - mean_squared_error: 258.0141Batch Count:  63
# 56/77 [====================>.........] - ETA: 6s - loss: 44.3076 - mean_squared_error: 257.9091Batch Count:  45
# 57/77 [=====================>........] - ETA: 5s - loss: 44.2934 - mean_squared_error: 257.7667Batch Count:  34
# 58/77 [=====================>........] - ETA: 5s - loss: 44.2424 - mean_squared_error: 257.1549Batch Count:  24
# 59/77 [=====================>........] - ETA: 5s - loss: 44.2348 - mean_squared_error: 257.0881Batch Count:  22
# 60/77 [======================>.......] - ETA: 4s - loss: 44.2054 - mean_squared_error: 256.7107Batch Count:  30
# 61/77 [======================>.......] - ETA: 4s - loss: 44.2165 - mean_squared_error: 256.8659Batch Count:  25
# 62/77 [=======================>......] - ETA: 4s - loss: 44.2145 - mean_squared_error: 256.8873Batch Count:  3
# 63/77 [=======================>......] - ETA: 4s - loss: 44.2498 - mean_squared_error: 257.2726Batch Count:  61
# 64/77 [=======================>......] - ETA: 3s - loss: 44.2560 - mean_squared_error: 257.5242Batch Count:  55
# 65/77 [========================>.....] - ETA: 3s - loss: 44.2352 - mean_squared_error: 257.3659Batch Count:  56
# 66/77 [========================>.....] - ETA: 3s - loss: 44.2187 - mean_squared_error: 257.1573Batch Count:  46
# 67/77 [=========================>....] - ETA: 2s - loss: 44.2093 - mean_squared_error: 257.0020Batch Count:  64
# 68/77 [=========================>....] - ETA: 2s - loss: 44.2125 - mean_squared_error: 257.0285Batch Count:  39
# 69/77 [=========================>....] - ETA: 2s - loss: 44.2003 - mean_squared_error: 256.8949Batch Count:  17
# 70/77 [==========================>...] - ETA: 2s - loss: 44.1909 - mean_squared_error: 256.7511Batch Count:  50
# 71/77 [==========================>...] - ETA: 1s - loss: 44.1901 - mean_squared_error: 256.7055Batch Count:  0
# 72/77 [===========================>..] - ETA: 1s - loss: 44.1971 - mean_squared_error: 256.7588Batch Count:  27
# 73/77 [===========================>..] - ETA: 1s - loss: 44.1817 - mean_squared_error: 256.6502Batch Count:  62
# 74/77 [===========================>..] - ETA: 0s - loss: 44.1668 - mean_squared_error: 256.4770Batch Count:  59
# 75/77 [============================>.] - ETA: 0s - loss: 44.1452 - mean_squared_error: 256.2608Batch Count:  71
# 76/77 [============================>.] - ETA: 0s - loss: 44.1056 - mean_squared_error: 255.8122Batch Count:  3
# Epoch 00001: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-01-44.09.hdf5
# 77/77 [==============================] - 22s - loss: 44.0866 - mean_squared_error: 255.6201
# Epoch 3/50
# Batch Count:  54
#  1/77 [..............................] - ETA: 21s - loss: 38.8180 - mean_squared_error: 206.8471Batch Count:  15
#  2/77 [..............................] - ETA: 21s - loss: 41.2943 - mean_squared_error: 228.3336Batch Count:  21
#  3/77 [>.............................] - ETA: 21s - loss: 41.4829 - mean_squared_error: 230.5336Batch Count:  48
#  4/77 [>.............................] - ETA: 20s - loss: 41.2575 - mean_squared_error: 227.9531Batch Count:  38
#  5/77 [>.............................] - ETA: 20s - loss: 41.5366 - mean_squared_error: 230.2666Batch Count:  32
#  6/77 [=>............................] - ETA: 20s - loss: 41.9764 - mean_squared_error: 234.0485Batch Count:  12
#  7/77 [=>............................] - ETA: 20s - loss: 42.3015 - mean_squared_error: 237.0152Batch Count:  7
#  8/77 [==>...........................] - ETA: 19s - loss: 42.3566 - mean_squared_error: 237.8469Batch Count:  66
#  9/77 [==>...........................] - ETA: 19s - loss: 42.2643 - mean_squared_error: 237.1696Batch Count:  69
# 10/77 [==>...........................] - ETA: 19s - loss: 42.2170 - mean_squared_error: 236.5964Batch Count:  70
# 11/77 [===>..........................] - ETA: 18s - loss: 42.2271 - mean_squared_error: 236.6797Batch Count:  41
# 12/77 [===>..........................] - ETA: 18s - loss: 42.2288 - mean_squared_error: 236.4274Batch Count:  75
# 13/77 [====>.........................] - ETA: 18s - loss: 42.1652 - mean_squared_error: 235.5704Batch Count:  28
# 14/77 [====>.........................] - ETA: 18s - loss: 42.1697 - mean_squared_error: 235.6506Batch Count:  60
# 15/77 [====>.........................] - ETA: 17s - loss: 42.0933 - mean_squared_error: 234.6914Batch Count:  61
# 16/77 [=====>........................] - ETA: 17s - loss: 42.1243 - mean_squared_error: 234.9925Batch Count:  9
# 17/77 [=====>........................] - ETA: 17s - loss: 42.0023 - mean_squared_error: 233.7098Batch Count:  24
# 18/77 [======>.......................] - ETA: 16s - loss: 42.0079 - mean_squared_error: 233.7157Batch Count:  72
# 19/77 [======>.......................] - ETA: 16s - loss: 42.0405 - mean_squared_error: 234.2977Batch Count:  22
# 20/77 [======>.......................] - ETA: 16s - loss: 42.0020 - mean_squared_error: 233.8168Batch Count:  55
# 21/77 [=======>......................] - ETA: 16s - loss: 42.0469 - mean_squared_error: 234.3722Batch Count:  44
# 22/77 [=======>......................] - ETA: 15s - loss: 42.0290 - mean_squared_error: 234.3288Batch Count:  65
# 23/77 [=======>......................] - ETA: 15s - loss: 41.9581 - mean_squared_error: 233.5824Batch Count:  67
# 24/77 [========>.....................] - ETA: 15s - loss: 41.8984 - mean_squared_error: 232.9391Batch Count:  45
# 25/77 [========>.....................] - ETA: 14s - loss: 41.9198 - mean_squared_error: 233.2046Batch Count:  68
# 26/77 [=========>....................] - ETA: 14s - loss: 41.9680 - mean_squared_error: 233.7299Batch Count:  57
# 27/77 [=========>....................] - ETA: 14s - loss: 41.9433 - mean_squared_error: 233.7213Batch Count:  43
# 28/77 [=========>....................] - ETA: 14s - loss: 41.9910 - mean_squared_error: 234.1236Batch Count:  56
# 29/77 [==========>...................] - ETA: 13s - loss: 42.0491 - mean_squared_error: 234.7125Batch Count:  1
# 30/77 [==========>...................] - ETA: 13s - loss: 42.0358 - mean_squared_error: 234.5726Batch Count:  74
# 31/77 [===========>..................] - ETA: 13s - loss: 42.0159 - mean_squared_error: 234.3971Batch Count:  4
# 32/77 [===========>..................] - ETA: 12s - loss: 41.9940 - mean_squared_error: 234.2101Batch Count:  31
# 33/77 [===========>..................] - ETA: 12s - loss: 41.9428 - mean_squared_error: 233.6054Batch Count:  37
# 34/77 [============>.................] - ETA: 12s - loss: 41.9470 - mean_squared_error: 233.5371Batch Count:  34
# 35/77 [============>.................] - ETA: 12s - loss: 41.9205 - mean_squared_error: 233.2026Batch Count:  23
# 36/77 [=============>................] - ETA: 11s - loss: 41.9384 - mean_squared_error: 233.4741Batch Count:  36
# 37/77 [=============>................] - ETA: 11s - loss: 41.9591 - mean_squared_error: 233.7017Batch Count:  16
# 38/77 [=============>................] - ETA: 11s - loss: 41.9443 - mean_squared_error: 233.4560Batch Count:  11
# 39/77 [==============>...............] - ETA: 10s - loss: 41.9190 - mean_squared_error: 233.1861Batch Count:  30
# 40/77 [==============>...............] - ETA: 10s - loss: 41.8360 - mean_squared_error: 232.3750Batch Count:  13
# 41/77 [==============>...............] - ETA: 10s - loss: 41.8033 - mean_squared_error: 231.9861Batch Count:  33
# 42/77 [===============>..............] - ETA: 10s - loss: 41.8642 - mean_squared_error: 232.6832Batch Count:  49
# 43/77 [===============>..............] - ETA: 9s - loss: 41.7641 - mean_squared_error: 231.6622 Batch Count:  47
# 44/77 [================>.............] - ETA: 9s - loss: 41.7918 - mean_squared_error: 231.9927Batch Count:  20
# 45/77 [================>.............] - ETA: 9s - loss: 41.7734 - mean_squared_error: 231.7926Batch Count:  10
# 46/77 [================>.............] - ETA: 8s - loss: 41.7812 - mean_squared_error: 231.8399Batch Count:  29
# 47/77 [=================>............] - ETA: 8s - loss: 41.7383 - mean_squared_error: 231.4204Batch Count:  40
# 48/77 [=================>............] - ETA: 8s - loss: 41.7247 - mean_squared_error: 231.3660Batch Count:  14
# 49/77 [==================>...........] - ETA: 8s - loss: 41.7178 - mean_squared_error: 231.3735Batch Count:  76
# 50/77 [==================>...........] - ETA: 7s - loss: 41.7071 - mean_squared_error: 231.2807Batch Count:  2
# 51/77 [==================>...........] - ETA: 7s - loss: 41.6433 - mean_squared_error: 230.5790Batch Count:  42
# 52/77 [===================>..........] - ETA: 7s - loss: 41.6496 - mean_squared_error: 230.6541Batch Count:  58
# 53/77 [===================>..........] - ETA: 6s - loss: 41.6143 - mean_squared_error: 230.2943Batch Count:  5
# 54/77 [====================>.........] - ETA: 6s - loss: 41.5845 - mean_squared_error: 230.0196Batch Count:  18
# 55/77 [====================>.........] - ETA: 6s - loss: 41.6040 - mean_squared_error: 230.2989Batch Count:  73
# 56/77 [====================>.........] - ETA: 6s - loss: 41.5627 - mean_squared_error: 229.9423Batch Count:  25
# 57/77 [=====================>........] - ETA: 5s - loss: 41.6191 - mean_squared_error: 230.4867Batch Count:  26
# 58/77 [=====================>........] - ETA: 5s - loss: 41.6245 - mean_squared_error: 230.5171Batch Count:  52
# 59/77 [=====================>........] - ETA: 5s - loss: 41.5651 - mean_squared_error: 229.9646Batch Count:  19
# 60/77 [======================>.......] - ETA: 4s - loss: 41.5725 - mean_squared_error: 230.0085Batch Count:  8
# 61/77 [======================>.......] - ETA: 4s - loss: 41.5819 - mean_squared_error: 230.0876Batch Count:  53
# 62/77 [=======================>......] - ETA: 4s - loss: 41.6323 - mean_squared_error: 230.5974Batch Count:  63
# 63/77 [=======================>......] - ETA: 4s - loss: 41.5983 - mean_squared_error: 230.2237Batch Count:  35
# 64/77 [=======================>......] - ETA: 3s - loss: 41.6108 - mean_squared_error: 230.3957Batch Count:  6
# 65/77 [========================>.....] - ETA: 3s - loss: 41.5917 - mean_squared_error: 230.2084Batch Count:  51
# 66/77 [========================>.....] - ETA: 3s - loss: 41.5401 - mean_squared_error: 229.6889Batch Count:  17
# 67/77 [=========================>....] - ETA: 2s - loss: 41.5410 - mean_squared_error: 229.6764Batch Count:  24
# 68/77 [=========================>....] - ETA: 2s - loss: 41.5327 - mean_squared_error: 229.5747Batch Count:  25
# 69/77 [=========================>....] - ETA: 2s - loss: 41.5137 - mean_squared_error: 229.3769Batch Count:  57
# 70/77 [==========================>...] - ETA: 2s - loss: 41.4837 - mean_squared_error: 229.0547Batch Count:  59
# 71/77 [==========================>...] - ETA: 1s - loss: 41.4760 - mean_squared_error: 228.9533Batch Count:  3
# 72/77 [===========================>..] - ETA: 1s - loss: 41.4743 - mean_squared_error: 228.9445Batch Count:  68
# 73/77 [===========================>..] - ETA: 1s - loss: 41.4651 - mean_squared_error: 228.8438Batch Count:  1
# 74/77 [===========================>..] - ETA: 0s - loss: 41.4449 - mean_squared_error: 228.5904Batch Count:  55
# 75/77 [============================>.] - ETA: 0s - loss: 41.4402 - mean_squared_error: 228.5350Batch Count:  72
# 76/77 [============================>.] - ETA: 0s - loss: 41.4200 - mean_squared_error: 228.2930Batch Count:  26
# Epoch 00002: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-02-41.41.hdf5
# 77/77 [==============================] - 22s - loss: 41.4051 - mean_squared_error: 228.1178
# Epoch 4/50
# Batch Count:  23
#  1/77 [..............................] - ETA: 21s - loss: 36.7953 - mean_squared_error: 185.0800Batch Count:  46
#  2/77 [..............................] - ETA: 21s - loss: 37.0664 - mean_squared_error: 186.2117Batch Count:  58
#  3/77 [>.............................] - ETA: 21s - loss: 37.6502 - mean_squared_error: 190.5852Batch Count:  53
#  4/77 [>.............................] - ETA: 21s - loss: 38.3974 - mean_squared_error: 197.9503Batch Count:  15
#  5/77 [>.............................] - ETA: 20s - loss: 38.0420 - mean_squared_error: 194.4793Batch Count:  35
#  6/77 [=>............................] - ETA: 20s - loss: 37.8096 - mean_squared_error: 192.6076Batch Count:  39
#  7/77 [=>............................] - ETA: 20s - loss: 37.7269 - mean_squared_error: 192.3179Batch Count:  9
#  8/77 [==>...........................] - ETA: 19s - loss: 37.5965 - mean_squared_error: 191.5682Batch Count:  51
#  9/77 [==>...........................] - ETA: 19s - loss: 37.8367 - mean_squared_error: 193.9089Batch Count:  74
# 10/77 [==>...........................] - ETA: 19s - loss: 38.0540 - mean_squared_error: 196.1694Batch Count:  14
# 11/77 [===>..........................] - ETA: 19s - loss: 37.9247 - mean_squared_error: 194.7450Batch Count:  49
# 12/77 [===>..........................] - ETA: 18s - loss: 38.3298 - mean_squared_error: 198.8211Batch Count:  33
# 13/77 [====>.........................] - ETA: 18s - loss: 38.4120 - mean_squared_error: 199.6369Batch Count:  36
# 14/77 [====>.........................] - ETA: 18s - loss: 38.3773 - mean_squared_error: 199.3305Batch Count:  70
# 15/77 [====>.........................] - ETA: 17s - loss: 38.3752 - mean_squared_error: 199.2770Batch Count:  65
# 16/77 [=====>........................] - ETA: 17s - loss: 38.4322 - mean_squared_error: 199.6641Batch Count:  16
# 17/77 [=====>........................] - ETA: 17s - loss: 38.4043 - mean_squared_error: 199.4474Batch Count:  30
# 18/77 [======>.......................] - ETA: 17s - loss: 38.5084 - mean_squared_error: 200.4898Batch Count:  13
# 19/77 [======>.......................] - ETA: 16s - loss: 38.5617 - mean_squared_error: 200.9530Batch Count:  29
# 20/77 [======>.......................] - ETA: 16s - loss: 38.4413 - mean_squared_error: 199.7082Batch Count:  0
# 21/77 [=======>......................] - ETA: 16s - loss: 38.5000 - mean_squared_error: 200.4109Batch Count:  63
# 22/77 [=======>......................] - ETA: 15s - loss: 38.6251 - mean_squared_error: 201.5455Batch Count:  44
# 23/77 [=======>......................] - ETA: 15s - loss: 38.7426 - mean_squared_error: 202.6315Batch Count:  27
# 24/77 [========>.....................] - ETA: 15s - loss: 38.7771 - mean_squared_error: 203.1397Batch Count:  48
# 25/77 [========>.....................] - ETA: 15s - loss: 38.8218 - mean_squared_error: 203.4089Batch Count:  4
# 26/77 [=========>....................] - ETA: 14s - loss: 38.7933 - mean_squared_error: 203.1236Batch Count:  20
# 27/77 [=========>....................] - ETA: 14s - loss: 38.7987 - mean_squared_error: 203.1115Batch Count:  76
# 28/77 [=========>....................] - ETA: 14s - loss: 38.8228 - mean_squared_error: 203.3743Batch Count:  12
# 29/77 [==========>...................] - ETA: 13s - loss: 38.8580 - mean_squared_error: 203.6171Batch Count:  60
# 30/77 [==========>...................] - ETA: 13s - loss: 38.8885 - mean_squared_error: 203.9260Batch Count:  62
# 31/77 [===========>..................] - ETA: 13s - loss: 38.8551 - mean_squared_error: 203.6945Batch Count:  10
# 32/77 [===========>..................] - ETA: 13s - loss: 38.8909 - mean_squared_error: 203.8553Batch Count:  75
# 33/77 [===========>..................] - ETA: 12s - loss: 38.8343 - mean_squared_error: 203.2757Batch Count:  5
# 34/77 [============>.................] - ETA: 12s - loss: 38.8291 - mean_squared_error: 203.4252Batch Count:  69
# 35/77 [============>.................] - ETA: 12s - loss: 38.8033 - mean_squared_error: 203.1919Batch Count:  38
# 36/77 [=============>................] - ETA: 11s - loss: 38.8400 - mean_squared_error: 203.5513Batch Count:  56
# 37/77 [=============>................] - ETA: 11s - loss: 38.8390 - mean_squared_error: 203.6017Batch Count:  45
# 38/77 [=============>................] - ETA: 11s - loss: 38.8201 - mean_squared_error: 203.4369Batch Count:  21
# 39/77 [==============>...............] - ETA: 10s - loss: 38.8676 - mean_squared_error: 203.8975Batch Count:  34
# 40/77 [==============>...............] - ETA: 10s - loss: 38.8781 - mean_squared_error: 203.9808Batch Count:  50
# 41/77 [==============>...............] - ETA: 10s - loss: 38.8812 - mean_squared_error: 203.8709Batch Count:  54
# 42/77 [===============>..............] - ETA: 10s - loss: 38.8546 - mean_squared_error: 203.5863Batch Count:  31
# 43/77 [===============>..............] - ETA: 9s - loss: 38.8765 - mean_squared_error: 203.7098 Batch Count:  43
# 44/77 [================>.............] - ETA: 9s - loss: 38.8716 - mean_squared_error: 203.7644Batch Count:  71
# 45/77 [================>.............] - ETA: 9s - loss: 38.9296 - mean_squared_error: 204.2993Batch Count:  8
# 46/77 [================>.............] - ETA: 8s - loss: 38.9751 - mean_squared_error: 204.6857Batch Count:  32
# 47/77 [=================>............] - ETA: 8s - loss: 38.9532 - mean_squared_error: 204.3727Batch Count:  40
# 48/77 [=================>............] - ETA: 8s - loss: 38.9822 - mean_squared_error: 204.6770Batch Count:  22
# 49/77 [==================>...........] - ETA: 8s - loss: 38.9780 - mean_squared_error: 204.6441Batch Count:  41
# 50/77 [==================>...........] - ETA: 7s - loss: 38.9937 - mean_squared_error: 204.8209Batch Count:  52
# 51/77 [==================>...........] - ETA: 7s - loss: 39.0500 - mean_squared_error: 205.3828Batch Count:  18
# 52/77 [===================>..........] - ETA: 7s - loss: 39.0336 - mean_squared_error: 205.1081Batch Count:  67
# 53/77 [===================>..........] - ETA: 6s - loss: 39.0263 - mean_squared_error: 205.0050Batch Count:  19
# 54/77 [====================>.........] - ETA: 6s - loss: 39.0452 - mean_squared_error: 205.2303Batch Count:  66
# 55/77 [====================>.........] - ETA: 6s - loss: 39.0428 - mean_squared_error: 205.2515Batch Count:  73
# 56/77 [====================>.........] - ETA: 6s - loss: 39.0341 - mean_squared_error: 205.0899Batch Count:  61
# 57/77 [=====================>........] - ETA: 5s - loss: 39.0517 - mean_squared_error: 205.2961Batch Count:  42
# 58/77 [=====================>........] - ETA: 5s - loss: 39.0323 - mean_squared_error: 205.0455Batch Count:  28
# 59/77 [=====================>........] - ETA: 5s - loss: 39.0386 - mean_squared_error: 205.0608Batch Count:  11
# 60/77 [======================>.......] - ETA: 4s - loss: 39.0531 - mean_squared_error: 205.2019Batch Count:  37
# 61/77 [======================>.......] - ETA: 4s - loss: 39.0779 - mean_squared_error: 205.4647Batch Count:  2
# 62/77 [=======================>......] - ETA: 4s - loss: 39.0962 - mean_squared_error: 205.6247Batch Count:  6
# 63/77 [=======================>......] - ETA: 4s - loss: 39.0916 - mean_squared_error: 205.6464Batch Count:  64
# 64/77 [=======================>......] - ETA: 3s - loss: 39.1236 - mean_squared_error: 205.9931Batch Count:  7
# 65/77 [========================>.....] - ETA: 3s - loss: 39.1481 - mean_squared_error: 206.2229Batch Count:  47
# 66/77 [========================>.....] - ETA: 3s - loss: 39.1304 - mean_squared_error: 206.0121Batch Count:  33
# 67/77 [=========================>....] - ETA: 2s - loss: 39.1256 - mean_squared_error: 205.9173Batch Count:  62
# 68/77 [=========================>....] - ETA: 2s - loss: 39.1519 - mean_squared_error: 206.2098Batch Count:  22
# 69/77 [=========================>....] - ETA: 2s - loss: 39.1637 - mean_squared_error: 206.3543Batch Count:  42
# 70/77 [==========================>...] - ETA: 2s - loss: 39.1367 - mean_squared_error: 206.0618Batch Count:  49
# 71/77 [==========================>...] - ETA: 1s - loss: 39.1444 - mean_squared_error: 206.1531Batch Count:  60
# 72/77 [===========================>..] - ETA: 1s - loss: 39.1274 - mean_squared_error: 205.9641Batch Count:  14
# 73/77 [===========================>..] - ETA: 1s - loss: 39.1228 - mean_squared_error: 205.9299Batch Count:  8
# 74/77 [===========================>..] - ETA: 0s - loss: 39.1224 - mean_squared_error: 205.9156Batch Count:  73
# 75/77 [============================>.] - ETA: 0s - loss: 39.1126 - mean_squared_error: 205.8155Batch Count:  46
# 76/77 [============================>.] - ETA: 0s - loss: 39.1078 - mean_squared_error: 205.7476Batch Count:  23
# Epoch 00003: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-03-39.08.hdf5
# 77/77 [==============================] - 22s - loss: 39.0758 - mean_squared_error: 205.4956
# Epoch 5/50
# Batch Count:  43
#  1/77 [..............................] - ETA: 22s - loss: 36.9864 - mean_squared_error: 186.0916Batch Count:  29
#  2/77 [..............................] - ETA: 21s - loss: 37.0958 - mean_squared_error: 186.5201Batch Count:  57
#  3/77 [>.............................] - ETA: 21s - loss: 35.9792 - mean_squared_error: 176.8614Batch Count:  61
#  4/77 [>.............................] - ETA: 21s - loss: 36.0911 - mean_squared_error: 177.4966Batch Count:  3
#  5/77 [>.............................] - ETA: 20s - loss: 36.2083 - mean_squared_error: 178.5776Batch Count:  9
#  6/77 [=>............................] - ETA: 20s - loss: 36.1943 - mean_squared_error: 177.6856Batch Count:  30
#  7/77 [=>............................] - ETA: 20s - loss: 36.3593 - mean_squared_error: 179.1581Batch Count:  63
#  8/77 [==>...........................] - ETA: 20s - loss: 36.2739 - mean_squared_error: 178.4294Batch Count:  26
#  9/77 [==>...........................] - ETA: 19s - loss: 36.1888 - mean_squared_error: 177.7902Batch Count:  28
# 10/77 [==>...........................] - ETA: 19s - loss: 36.2089 - mean_squared_error: 178.0174Batch Count:  4
# 11/77 [===>..........................] - ETA: 19s - loss: 36.1958 - mean_squared_error: 177.5243Batch Count:  65
# 12/77 [===>..........................] - ETA: 18s - loss: 36.2959 - mean_squared_error: 178.2876Batch Count:  69
# 13/77 [====>.........................] - ETA: 18s - loss: 36.1765 - mean_squared_error: 177.2275Batch Count:  58
# 14/77 [====>.........................] - ETA: 18s - loss: 36.1074 - mean_squared_error: 176.3760Batch Count:  41
# 15/77 [====>.........................] - ETA: 18s - loss: 36.2087 - mean_squared_error: 177.4142Batch Count:  71
# 16/77 [=====>........................] - ETA: 17s - loss: 35.9899 - mean_squared_error: 175.3081Batch Count:  40
# 17/77 [=====>........................] - ETA: 17s - loss: 36.0672 - mean_squared_error: 176.1455Batch Count:  24
# 18/77 [======>.......................] - ETA: 17s - loss: 36.1499 - mean_squared_error: 176.8829Batch Count:  5
# 19/77 [======>.......................] - ETA: 16s - loss: 36.0621 - mean_squared_error: 176.2681Batch Count:  38
# 20/77 [======>.......................] - ETA: 16s - loss: 36.1451 - mean_squared_error: 177.2074Batch Count:  44
# 21/77 [=======>......................] - ETA: 16s - loss: 36.1143 - mean_squared_error: 176.8411Batch Count:  37
# 22/77 [=======>......................] - ETA: 15s - loss: 36.0567 - mean_squared_error: 176.1583Batch Count:  21
# 23/77 [=======>......................] - ETA: 15s - loss: 35.9921 - mean_squared_error: 175.6067Batch Count:  39
# 24/77 [========>.....................] - ETA: 15s - loss: 36.1580 - mean_squared_error: 177.3832Batch Count:  18
# 25/77 [========>.....................] - ETA: 15s - loss: 36.1358 - mean_squared_error: 177.0876Batch Count:  52
# 26/77 [=========>....................] - ETA: 14s - loss: 36.1758 - mean_squared_error: 177.5082Batch Count:  17
# 27/77 [=========>....................] - ETA: 14s - loss: 36.2099 - mean_squared_error: 177.8896Batch Count:  68
# 28/77 [=========>....................] - ETA: 14s - loss: 36.1685 - mean_squared_error: 177.4286Batch Count:  35
# 29/77 [==========>...................] - ETA: 13s - loss: 36.1957 - mean_squared_error: 177.5508Batch Count:  7
# 30/77 [==========>...................] - ETA: 13s - loss: 36.1279 - mean_squared_error: 176.8475Batch Count:  48
# 31/77 [===========>..................] - ETA: 13s - loss: 36.1613 - mean_squared_error: 177.1887Batch Count:  20
# 32/77 [===========>..................] - ETA: 13s - loss: 36.1528 - mean_squared_error: 177.1992Batch Count:  66
# 33/77 [===========>..................] - ETA: 12s - loss: 36.1814 - mean_squared_error: 177.4494Batch Count:  76
# 34/77 [============>.................] - ETA: 12s - loss: 36.2167 - mean_squared_error: 177.8122Batch Count:  32
# 35/77 [============>.................] - ETA: 12s - loss: 36.2044 - mean_squared_error: 177.6709Batch Count:  75
# 36/77 [=============>................] - ETA: 11s - loss: 36.2355 - mean_squared_error: 178.0727Batch Count:  47
# 37/77 [=============>................] - ETA: 11s - loss: 36.2057 - mean_squared_error: 177.7811Batch Count:  72
# 38/77 [=============>................] - ETA: 11s - loss: 36.2789 - mean_squared_error: 178.5422Batch Count:  34
# 39/77 [==============>...............] - ETA: 11s - loss: 36.2970 - mean_squared_error: 178.7142Batch Count:  55
# 40/77 [==============>...............] - ETA: 10s - loss: 36.2826 - mean_squared_error: 178.5047Batch Count:  27
# 41/77 [==============>...............] - ETA: 10s - loss: 36.3690 - mean_squared_error: 179.2453Batch Count:  16
# 42/77 [===============>..............] - ETA: 10s - loss: 36.3702 - mean_squared_error: 179.2097Batch Count:  54
# 43/77 [===============>..............] - ETA: 9s - loss: 36.4392 - mean_squared_error: 179.9333 Batch Count:  56
# 44/77 [================>.............] - ETA: 9s - loss: 36.4270 - mean_squared_error: 179.9075Batch Count:  25
# 45/77 [================>.............] - ETA: 9s - loss: 36.4156 - mean_squared_error: 179.7645Batch Count:  6
# 46/77 [================>.............] - ETA: 9s - loss: 36.4101 - mean_squared_error: 179.7553Batch Count:  12
# 47/77 [=================>............] - ETA: 8s - loss: 36.4045 - mean_squared_error: 179.6662Batch Count:  31
# 48/77 [=================>............] - ETA: 8s - loss: 36.4169 - mean_squared_error: 179.8921Batch Count:  2
# 49/77 [==================>...........] - ETA: 8s - loss: 36.4275 - mean_squared_error: 180.0180Batch Count:  19
# 50/77 [==================>...........] - ETA: 7s - loss: 36.4688 - mean_squared_error: 180.4170Batch Count:  50
# 51/77 [==================>...........] - ETA: 7s - loss: 36.4498 - mean_squared_error: 180.3337Batch Count:  53
# 52/77 [===================>..........] - ETA: 7s - loss: 36.4679 - mean_squared_error: 180.5392Batch Count:  64
# 53/77 [===================>..........] - ETA: 6s - loss: 36.4995 - mean_squared_error: 180.7808Batch Count:  70
# 54/77 [====================>.........] - ETA: 6s - loss: 36.5042 - mean_squared_error: 180.9007Batch Count:  67
# 55/77 [====================>.........] - ETA: 6s - loss: 36.5089 - mean_squared_error: 180.8832Batch Count:  10
# 56/77 [====================>.........] - ETA: 6s - loss: 36.4983 - mean_squared_error: 180.7509Batch Count:  51
# 57/77 [=====================>........] - ETA: 5s - loss: 36.5261 - mean_squared_error: 181.0111Batch Count:  13
# 58/77 [=====================>........] - ETA: 5s - loss: 36.5310 - mean_squared_error: 181.1173Batch Count:  0
# 59/77 [=====================>........] - ETA: 5s - loss: 36.5156 - mean_squared_error: 180.9662Batch Count:  11
# 60/77 [======================>.......] - ETA: 4s - loss: 36.4684 - mean_squared_error: 180.5524Batch Count:  45
# 61/77 [======================>.......] - ETA: 4s - loss: 36.5019 - mean_squared_error: 180.9574Batch Count:  59
# 62/77 [=======================>......] - ETA: 4s - loss: 36.5269 - mean_squared_error: 181.2178Batch Count:  15
# 63/77 [=======================>......] - ETA: 4s - loss: 36.5141 - mean_squared_error: 181.1159Batch Count:  1
# 64/77 [=======================>......] - ETA: 3s - loss: 36.5789 - mean_squared_error: 181.7645Batch Count:  74
# 65/77 [========================>.....] - ETA: 3s - loss: 36.5739 - mean_squared_error: 181.6877Batch Count:  36
# 66/77 [========================>.....] - ETA: 3s - loss: 36.6019 - mean_squared_error: 181.9110Batch Count:  47
# 67/77 [=========================>....] - ETA: 2s - loss: 36.5719 - mean_squared_error: 181.6293Batch Count:  13
# 68/77 [=========================>....] - ETA: 2s - loss: 36.5603 - mean_squared_error: 181.5862Batch Count:  54
# 69/77 [=========================>....] - ETA: 2s - loss: 36.5565 - mean_squared_error: 181.5368Batch Count:  19
# 70/77 [==========================>...] - ETA: 2s - loss: 36.5406 - mean_squared_error: 181.3726Batch Count:  21
# 71/77 [==========================>...] - ETA: 1s - loss: 36.5272 - mean_squared_error: 181.3056Batch Count:  70
# 72/77 [===========================>..] - ETA: 1s - loss: 36.5438 - mean_squared_error: 181.4757Batch Count:  66
# 73/77 [===========================>..] - ETA: 1s - loss: 36.5171 - mean_squared_error: 181.2240Batch Count:  33
# 74/77 [===========================>..] - ETA: 0s - loss: 36.4732 - mean_squared_error: 180.8210Batch Count:  44
# 75/77 [============================>.] - ETA: 0s - loss: 36.5002 - mean_squared_error: 181.1064Batch Count:  26
# 76/77 [============================>.] - ETA: 0s - loss: 36.4541 - mean_squared_error: 180.7026Batch Count:  73
# Epoch 00004: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-04-36.45.hdf5
# 77/77 [==============================] - 22s - loss: 36.4536 - mean_squared_error: 180.7170
# Epoch 6/50
# Batch Count:  4
#  1/77 [..............................] - ETA: 22s - loss: 33.8955 - mean_squared_error: 158.3147Batch Count:  15
#  2/77 [..............................] - ETA: 21s - loss: 33.4753 - mean_squared_error: 154.8428Batch Count:  0
#  3/77 [>.............................] - ETA: 21s - loss: 33.8891 - mean_squared_error: 157.9928Batch Count:  38
#  4/77 [>.............................] - ETA: 21s - loss: 33.1907 - mean_squared_error: 151.3780Batch Count:  28
#  5/77 [>.............................] - ETA: 21s - loss: 33.3414 - mean_squared_error: 152.8546Batch Count:  42
#  6/77 [=>............................] - ETA: 20s - loss: 33.2477 - mean_squared_error: 151.3866Batch Count:  59
#  7/77 [=>............................] - ETA: 20s - loss: 33.3604 - mean_squared_error: 152.2499Batch Count:  9
#  8/77 [==>...........................] - ETA: 20s - loss: 33.3390 - mean_squared_error: 152.3895Batch Count:  76
#  9/77 [==>...........................] - ETA: 19s - loss: 33.2821 - mean_squared_error: 152.2251Batch Count:  55
# 10/77 [==>...........................] - ETA: 19s - loss: 33.3275 - mean_squared_error: 152.4957Batch Count:  64
# 11/77 [===>..........................] - ETA: 19s - loss: 33.4681 - mean_squared_error: 154.0500Batch Count:  40
# 12/77 [===>..........................] - ETA: 18s - loss: 33.3528 - mean_squared_error: 152.9590Batch Count:  18
# 13/77 [====>.........................] - ETA: 18s - loss: 33.3145 - mean_squared_error: 152.4672Batch Count:  10
# 14/77 [====>.........................] - ETA: 18s - loss: 33.4451 - mean_squared_error: 153.6613Batch Count:  11
# 15/77 [====>.........................] - ETA: 18s - loss: 33.4230 - mean_squared_error: 153.8083Batch Count:  2
# 16/77 [=====>........................] - ETA: 17s - loss: 33.6481 - mean_squared_error: 156.1798Batch Count:  43
# 17/77 [=====>........................] - ETA: 17s - loss: 33.6389 - mean_squared_error: 156.1229Batch Count:  53
# 18/77 [======>.......................] - ETA: 17s - loss: 33.5809 - mean_squared_error: 155.7574Batch Count:  57
# 19/77 [======>.......................] - ETA: 16s - loss: 33.5200 - mean_squared_error: 155.0354Batch Count:  12
# 20/77 [======>.......................] - ETA: 16s - loss: 33.5699 - mean_squared_error: 155.3411Batch Count:  68
# 21/77 [=======>......................] - ETA: 16s - loss: 33.5605 - mean_squared_error: 155.1875Batch Count:  34
# 22/77 [=======>......................] - ETA: 16s - loss: 33.5536 - mean_squared_error: 155.1535Batch Count:  6
# 23/77 [=======>......................] - ETA: 15s - loss: 33.4698 - mean_squared_error: 154.3772Batch Count:  72
# 24/77 [========>.....................] - ETA: 15s - loss: 33.5513 - mean_squared_error: 155.1793Batch Count:  56
# 25/77 [========>.....................] - ETA: 15s - loss: 33.5429 - mean_squared_error: 155.2084Batch Count:  37
# 26/77 [=========>....................] - ETA: 14s - loss: 33.6125 - mean_squared_error: 155.9680Batch Count:  50
# 27/77 [=========>....................] - ETA: 14s - loss: 33.6499 - mean_squared_error: 156.3811Batch Count:  22
# 28/77 [=========>....................] - ETA: 14s - loss: 33.6768 - mean_squared_error: 156.6223Batch Count:  52
# 29/77 [==========>...................] - ETA: 14s - loss: 33.7752 - mean_squared_error: 157.4697Batch Count:  41
# 30/77 [==========>...................] - ETA: 13s - loss: 33.7897 - mean_squared_error: 157.6496Batch Count:  5
# 31/77 [===========>..................] - ETA: 13s - loss: 33.8588 - mean_squared_error: 158.1734Batch Count:  74
# 32/77 [===========>..................] - ETA: 13s - loss: 33.7982 - mean_squared_error: 157.6080Batch Count:  36
# 33/77 [===========>..................] - ETA: 12s - loss: 33.8017 - mean_squared_error: 157.6781Batch Count:  45
# 34/77 [============>.................] - ETA: 12s - loss: 33.8032 - mean_squared_error: 157.6517Batch Count:  69
# ...
# 14/77 [====>.........................] - ETA: 18s - loss: 15.2734 - mean_squared_error: 32.4543Batch Count:  69
# 15/77 [====>.........................] - ETA: 18s - loss: 15.3002 - mean_squared_error: 32.5994Batch Count:  37
# 16/77 [=====>........................] - ETA: 17s - loss: 15.2292 - mean_squared_error: 32.2797Batch Count:  68
# 17/77 [=====>........................] - ETA: 17s - loss: 15.2263 - mean_squared_error: 32.2321Batch Count:  0
# 18/77 [======>.......................] - ETA: 17s - loss: 15.2151 - mean_squared_error: 32.1695Batch Count:  23
# 19/77 [======>.......................] - ETA: 17s - loss: 15.2356 - mean_squared_error: 32.2457Batch Count:  76
# 20/77 [======>.......................] - ETA: 16s - loss: 15.1808 - mean_squared_error: 31.9745Batch Count:  29
# 21/77 [=======>......................] - ETA: 16s - loss: 15.1484 - mean_squared_error: 31.7985Batch Count:  34
# 22/77 [=======>......................] - ETA: 16s - loss: 15.1607 - mean_squared_error: 31.8442Batch Count:  19
# 23/77 [=======>......................] - ETA: 15s - loss: 15.1844 - mean_squared_error: 31.9732Batch Count:  75
# 24/77 [========>.....................] - ETA: 15s - loss: 15.2494 - mean_squared_error: 32.2377Batch Count:  40
# 25/77 [========>.....................] - ETA: 15s - loss: 15.2091 - mean_squared_error: 32.0723Batch Count:  33
# 26/77 [=========>....................] - ETA: 14s - loss: 15.1975 - mean_squared_error: 31.9798Batch Count:  13
# 27/77 [=========>....................] - ETA: 14s - loss: 15.1860 - mean_squared_error: 31.9161Batch Count:  3
# 28/77 [=========>....................] - ETA: 14s - loss: 15.1635 - mean_squared_error: 31.8042Batch Count:  24
# 29/77 [==========>...................] - ETA: 14s - loss: 15.1519 - mean_squared_error: 31.7372Batch Count:  42
# 30/77 [==========>...................] - ETA: 13s - loss: 15.1463 - mean_squared_error: 31.6924Batch Count:  65
# 31/77 [===========>..................] - ETA: 13s - loss: 15.1153 - mean_squared_error: 31.5649Batch Count:  2
# 32/77 [===========>..................] - ETA: 13s - loss: 15.1320 - mean_squared_error: 31.6653Batch Count:  32
# 33/77 [===========>..................] - ETA: 12s - loss: 15.1052 - mean_squared_error: 31.5450Batch Count:  73
# 34/77 [============>.................] - ETA: 12s - loss: 15.1092 - mean_squared_error: 31.5591Batch Count:  54
# 35/77 [============>.................] - ETA: 12s - loss: 15.1199 - mean_squared_error: 31.6445Batch Count:  8
# 36/77 [=============>................] - ETA: 12s - loss: 15.1279 - mean_squared_error: 31.6568Batch Count:  53
# 37/77 [=============>................] - ETA: 11s - loss: 15.1108 - mean_squared_error: 31.5731Batch Count:  38
# 38/77 [=============>................] - ETA: 11s - loss: 15.0888 - mean_squared_error: 31.5034Batch Count:  62
# 39/77 [==============>...............] - ETA: 11s - loss: 15.1040 - mean_squared_error: 31.5741Batch Count:  43
# 40/77 [==============>...............] - ETA: 10s - loss: 15.0928 - mean_squared_error: 31.5476Batch Count:  1
# 41/77 [==============>...............] - ETA: 10s - loss: 15.0847 - mean_squared_error: 31.5228Batch Count:  41
# 42/77 [===============>..............] - ETA: 10s - loss: 15.0970 - mean_squared_error: 31.5560Batch Count:  58
# 43/77 [===============>..............] - ETA: 10s - loss: 15.1135 - mean_squared_error: 31.6406Batch Count:  9
# 44/77 [================>.............] - ETA: 9s - loss: 15.1103 - mean_squared_error: 31.6162 Batch Count:  61
# 45/77 [================>.............] - ETA: 9s - loss: 15.0962 - mean_squared_error: 31.5498Batch Count:  10
# 46/77 [================>.............] - ETA: 9s - loss: 15.1032 - mean_squared_error: 31.5624Batch Count:  74
# 47/77 [=================>............] - ETA: 8s - loss: 15.1017 - mean_squared_error: 31.5617Batch Count:  47
# 48/77 [=================>............] - ETA: 8s - loss: 15.0906 - mean_squared_error: 31.5164Batch Count:  59
# 49/77 [==================>...........] - ETA: 8s - loss: 15.0711 - mean_squared_error: 31.4386Batch Count:  46
# 50/77 [==================>...........] - ETA: 7s - loss: 15.0660 - mean_squared_error: 31.4256Batch Count:  70
# 51/77 [==================>...........] - ETA: 7s - loss: 15.0504 - mean_squared_error: 31.3676Batch Count:  60
# 52/77 [===================>..........] - ETA: 7s - loss: 15.0486 - mean_squared_error: 31.3682Batch Count:  27
# 53/77 [===================>..........] - ETA: 7s - loss: 15.0474 - mean_squared_error: 31.3538Batch Count:  35
# 54/77 [====================>.........] - ETA: 6s - loss: 15.0459 - mean_squared_error: 31.3297Batch Count:  72
# 55/77 [====================>.........] - ETA: 6s - loss: 15.0384 - mean_squared_error: 31.2982Batch Count:  49
# 56/77 [====================>.........] - ETA: 6s - loss: 15.0502 - mean_squared_error: 31.3491Batch Count:  44
# 57/77 [=====================>........] - ETA: 5s - loss: 15.0405 - mean_squared_error: 31.3025Batch Count:  22
# 58/77 [=====================>........] - ETA: 5s - loss: 15.0585 - mean_squared_error: 31.3827Batch Count:  26
# 59/77 [=====================>........] - ETA: 5s - loss: 15.0700 - mean_squared_error: 31.4296Batch Count:  36
# 60/77 [======================>.......] - ETA: 5s - loss: 15.0842 - mean_squared_error: 31.4839Batch Count:  30
# 61/77 [======================>.......] - ETA: 4s - loss: 15.0766 - mean_squared_error: 31.4438Batch Count:  50
# 62/77 [=======================>......] - ETA: 4s - loss: 15.0976 - mean_squared_error: 31.5384Batch Count:  66
# 63/77 [=======================>......] - ETA: 4s - loss: 15.0842 - mean_squared_error: 31.4781Batch Count:  21
# 64/77 [=======================>......] - ETA: 3s - loss: 15.0894 - mean_squared_error: 31.5056Batch Count:  17
# 65/77 [========================>.....] - ETA: 3s - loss: 15.0965 - mean_squared_error: 31.5441Batch Count:  14
# 66/77 [========================>.....] - ETA: 3s - loss: 15.0843 - mean_squared_error: 31.4904Batch Count:  73
# 67/77 [=========================>....] - ETA: 2s - loss: 15.0869 - mean_squared_error: 31.5339Batch Count:  14
# 68/77 [=========================>....] - ETA: 2s - loss: 15.0833 - mean_squared_error: 31.5221Batch Count:  20
# 69/77 [=========================>....] - ETA: 2s - loss: 15.0669 - mean_squared_error: 31.4585Batch Count:  37
# 70/77 [==========================>...] - ETA: 2s - loss: 15.0586 - mean_squared_error: 31.4358Batch Count:  74
# 71/77 [==========================>...] - ETA: 1s - loss: 15.0726 - mean_squared_error: 31.5001Batch Count:  41
# 72/77 [===========================>..] - ETA: 1s - loss: 15.0715 - mean_squared_error: 31.4914Batch Count:  8
# 73/77 [===========================>..] - ETA: 1s - loss: 15.0802 - mean_squared_error: 31.5185Batch Count:  26
# 74/77 [===========================>..] - ETA: 0s - loss: 15.0779 - mean_squared_error: 31.5161Batch Count:  75
# 75/77 [============================>.] - ETA: 0s - loss: 15.0806 - mean_squared_error: 31.5274Batch Count:  44
# 76/77 [============================>.] - ETA: 0s - loss: 15.1058 - mean_squared_error: 31.6335Batch Count:  67
# Epoch 00048: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-48-15.09.hdf5
# 77/77 [==============================] - 22s - loss: 15.0938 - mean_squared_error: 31.5880
# Epoch 50/50
# Batch Count:  33
#  1/77 [..............................] - ETA: 21s - loss: 14.2168 - mean_squared_error: 28.1880Batch Count:  24
#  2/77 [..............................] - ETA: 22s - loss: 14.3843 - mean_squared_error: 28.5584Batch Count:  39
#  3/77 [>.............................] - ETA: 21s - loss: 14.5948 - mean_squared_error: 29.4980Batch Count:  59
#  4/77 [>.............................] - ETA: 21s - loss: 14.7103 - mean_squared_error: 30.3560Batch Count:  63
#  5/77 [>.............................] - ETA: 21s - loss: 14.5822 - mean_squared_error: 29.7713Batch Count:  72
#  6/77 [=>............................] - ETA: 20s - loss: 14.5719 - mean_squared_error: 29.6867Batch Count:  51
#  7/77 [=>............................] - ETA: 20s - loss: 14.5346 - mean_squared_error: 29.3944Batch Count:  7
#  8/77 [==>...........................] - ETA: 20s - loss: 14.4110 - mean_squared_error: 28.9137Batch Count:  2
#  9/77 [==>...........................] - ETA: 19s - loss: 14.4179 - mean_squared_error: 28.9147Batch Count:  27
# 10/77 [==>...........................] - ETA: 19s - loss: 14.4200 - mean_squared_error: 28.9511Batch Count:  56
# 11/77 [===>..........................] - ETA: 19s - loss: 14.5806 - mean_squared_error: 29.5419Batch Count:  23
# 12/77 [===>..........................] - ETA: 19s - loss: 14.6597 - mean_squared_error: 29.8188Batch Count:  6
# 13/77 [====>.........................] - ETA: 18s - loss: 14.7772 - mean_squared_error: 30.4096Batch Count:  18
# 14/77 [====>.........................] - ETA: 18s - loss: 14.7796 - mean_squared_error: 30.4970Batch Count:  29
# 15/77 [====>.........................] - ETA: 18s - loss: 14.8695 - mean_squared_error: 30.8944Batch Count:  28
# 16/77 [=====>........................] - ETA: 17s - loss: 14.8716 - mean_squared_error: 30.8818Batch Count:  25
# 17/77 [=====>........................] - ETA: 17s - loss: 14.9250 - mean_squared_error: 31.0518Batch Count:  50
# 18/77 [======>.......................] - ETA: 17s - loss: 14.8988 - mean_squared_error: 30.9797Batch Count:  10
# 19/77 [======>.......................] - ETA: 17s - loss: 14.8958 - mean_squared_error: 30.9820Batch Count:  5
# 20/77 [======>.......................] - ETA: 16s - loss: 14.9221 - mean_squared_error: 31.1052Batch Count:  1
# 21/77 [=======>......................] - ETA: 16s - loss: 14.9008 - mean_squared_error: 31.0053Batch Count:  4
# 22/77 [=======>......................] - ETA: 16s - loss: 14.8378 - mean_squared_error: 30.7036Batch Count:  69
# 23/77 [=======>......................] - ETA: 16s - loss: 14.8361 - mean_squared_error: 30.6962Batch Count:  21
# 24/77 [========>.....................] - ETA: 15s - loss: 14.8343 - mean_squared_error: 30.6567Batch Count:  48
# 25/77 [========>.....................] - ETA: 15s - loss: 14.8155 - mean_squared_error: 30.5861Batch Count:  71
# 26/77 [=========>....................] - ETA: 15s - loss: 14.8570 - mean_squared_error: 30.7751Batch Count:  22
# 27/77 [=========>....................] - ETA: 14s - loss: 14.8542 - mean_squared_error: 30.7531Batch Count:  31
# 28/77 [=========>....................] - ETA: 14s - loss: 14.8623 - mean_squared_error: 30.7654Batch Count:  36
# 29/77 [==========>...................] - ETA: 14s - loss: 14.8342 - mean_squared_error: 30.6437Batch Count:  35
# 30/77 [==========>...................] - ETA: 13s - loss: 14.8156 - mean_squared_error: 30.5574Batch Count:  12
# 31/77 [===========>..................] - ETA: 13s - loss: 14.8217 - mean_squared_error: 30.6051Batch Count:  70
# 32/77 [===========>..................] - ETA: 13s - loss: 14.8458 - mean_squared_error: 30.6965Batch Count:  38
# 33/77 [===========>..................] - ETA: 13s - loss: 14.8535 - mean_squared_error: 30.7196Batch Count:  43
# 34/77 [============>.................] - ETA: 12s - loss: 14.8484 - mean_squared_error: 30.7219Batch Count:  60
# 35/77 [============>.................] - ETA: 12s - loss: 14.8428 - mean_squared_error: 30.6981Batch Count:  47
# 36/77 [=============>................] - ETA: 12s - loss: 14.8416 - mean_squared_error: 30.6955Batch Count:  17
# 37/77 [=============>................] - ETA: 11s - loss: 14.8341 - mean_squared_error: 30.6434Batch Count:  3
# 38/77 [=============>................] - ETA: 11s - loss: 14.8601 - mean_squared_error: 30.7369Batch Count:  42
# 39/77 [==============>...............] - ETA: 11s - loss: 14.8927 - mean_squared_error: 30.8797Batch Count:  32
# 40/77 [==============>...............] - ETA: 10s - loss: 14.9090 - mean_squared_error: 30.9147Batch Count:  55
# 41/77 [==============>...............] - ETA: 10s - loss: 14.9131 - mean_squared_error: 30.9200Batch Count:  58
# 42/77 [===============>..............] - ETA: 10s - loss: 14.9070 - mean_squared_error: 30.9008Batch Count:  65
# 43/77 [===============>..............] - ETA: 10s - loss: 14.9055 - mean_squared_error: 30.8943Batch Count:  68
# 44/77 [================>.............] - ETA: 9s - loss: 14.9389 - mean_squared_error: 31.0442 Batch Count:  66
# 45/77 [================>.............] - ETA: 9s - loss: 14.9534 - mean_squared_error: 31.1059Batch Count:  19
# 46/77 [================>.............] - ETA: 9s - loss: 14.9472 - mean_squared_error: 31.0601Batch Count:  76
# 47/77 [=================>............] - ETA: 8s - loss: 14.9796 - mean_squared_error: 31.1908Batch Count:  11
# 48/77 [=================>............] - ETA: 8s - loss: 14.9797 - mean_squared_error: 31.1797Batch Count:  61
# 49/77 [==================>...........] - ETA: 8s - loss: 15.0069 - mean_squared_error: 31.2984Batch Count:  15
# 50/77 [==================>...........] - ETA: 7s - loss: 15.0153 - mean_squared_error: 31.3180Batch Count:  57
# 51/77 [==================>...........] - ETA: 7s - loss: 15.0070 - mean_squared_error: 31.2865Batch Count:  49
# 52/77 [===================>..........] - ETA: 7s - loss: 15.0004 - mean_squared_error: 31.2655Batch Count:  54
# 53/77 [===================>..........] - ETA: 7s - loss: 15.0186 - mean_squared_error: 31.3508Batch Count:  46
# 54/77 [====================>.........] - ETA: 6s - loss: 15.0492 - mean_squared_error: 31.4783Batch Count:  0
# 55/77 [====================>.........] - ETA: 6s - loss: 15.0464 - mean_squared_error: 31.4619Batch Count:  16
# 56/77 [====================>.........] - ETA: 6s - loss: 15.0610 - mean_squared_error: 31.5051Batch Count:  30
# 57/77 [=====================>........] - ETA: 5s - loss: 15.0900 - mean_squared_error: 31.6449Batch Count:  53
# 58/77 [=====================>........] - ETA: 5s - loss: 15.1092 - mean_squared_error: 31.7148Batch Count:  45
# 59/77 [=====================>........] - ETA: 5s - loss: 15.1206 - mean_squared_error: 31.7491Batch Count:  34
# 60/77 [======================>.......] - ETA: 5s - loss: 15.1696 - mean_squared_error: 31.9749Batch Count:  13
# 61/77 [======================>.......] - ETA: 4s - loss: 15.1657 - mean_squared_error: 31.9434Batch Count:  52
# 62/77 [=======================>......] - ETA: 4s - loss: 15.1665 - mean_squared_error: 31.9551Batch Count:  62
# 63/77 [=======================>......] - ETA: 4s - loss: 15.2010 - mean_squared_error: 32.1023Batch Count:  40
# 64/77 [=======================>......] - ETA: 3s - loss: 15.2105 - mean_squared_error: 32.1351Batch Count:  9
# 65/77 [========================>.....] - ETA: 3s - loss: 15.2175 - mean_squared_error: 32.1839Batch Count:  64
# 66/77 [========================>.....] - ETA: 3s - loss: 15.2147 - mean_squared_error: 32.1897Batch Count:  38
# 67/77 [=========================>....] - ETA: 2s - loss: 15.2468 - mean_squared_error: 32.3221Batch Count:  29
# 68/77 [=========================>....] - ETA: 2s - loss: 15.2579 - mean_squared_error: 32.3828Batch Count:  22
# 69/77 [=========================>....] - ETA: 2s - loss: 15.2959 - mean_squared_error: 32.5614Batch Count:  0
# 70/77 [==========================>...] - ETA: 2s - loss: 15.2999 - mean_squared_error: 32.5679Batch Count:  43
# 71/77 [==========================>...] - ETA: 1s - loss: 15.2926 - mean_squared_error: 32.5354Batch Count:  67
# 72/77 [===========================>..] - ETA: 1s - loss: 15.3153 - mean_squared_error: 32.6203Batch Count:  30
# 73/77 [===========================>..] - ETA: 1s - loss: 15.3385 - mean_squared_error: 32.7152Batch Count:  27
# 74/77 [===========================>..] - ETA: 0s - loss: 15.3380 - mean_squared_error: 32.7201Batch Count:  36
# 75/77 [============================>.] - ETA: 0s - loss: 15.3456 - mean_squared_error: 32.7620Batch Count:  8
# 76/77 [============================>.] - ETA: 0s - loss: 15.3515 - mean_squared_error: 32.8035Batch Count:  48
# Epoch 00049: saving model to /home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-49-15.37.hdf5
# 77/77 [==============================] - 23s - loss: 15.3653 - mean_squared_error: 32.8881

# %% [markdown]
# # Load Model and re run

# %%
from keras.models import load_model

with tf.device("gpu:0"):

    checkpoint = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/weights-02-27.96.hdf5"
    model = load_model(checkpoint, custom_objects={'euclidean_l2': euclidean_l2})

    print(model.summary())

    base_path = "/home/gokul/CMSC733/hgokul_p1/Phase2/Data"
    CheckPointPath = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised2/"
    files_in_dir, SaveCheckPoint, ImageSize, NumTrainSamples, labels_in_dir = SetupAll(base_path, CheckPointPath)

    ckptPath = CheckPointPath + "weights-{epoch:02d}-{loss:.2f}.hdf5"
    checkpoint = ModelCheckpoint(ckptPath, monitor='loss', verbose=1)

    epochs = 50
    number_of_training_samples = 4985
    batch_size = 64
    num_terations_per_epoch = int(number_of_training_samples / batch_size)

    generator = loadDataBatches_gen(base_path, files_in_dir, labels_in_dir, batch_size, True)
    
    
    print('TRAINING...')                             
    model.fit_generator(generator = generator,steps_per_epoch = num_terations_per_epoch,  epochs = epochs, callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:58: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:442: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3543: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3386: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1205: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2888: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:158: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1188: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/gokul/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:625: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 2)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      1216
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              33555456
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 8200
# =================================================================
# Total params: 34,195,336
# Trainable params: 34,193,800
# Non-trainable params: 1,536
# _________________________________________________________________
# None
# TRAINING...
# Epoch 1/50
# 20/77 [======>.......................] - ETA: 241s - loss: 27.9725 - mean_squared_error: 107.8698

# %% [markdown]
# # Test the model

# %%
from keras.models import load_model
from keras import optimizers

base_path = "/home/gokul/CMSC733/hgokul_p1/Phase2/Data"
CheckPointPath = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised/"
files_in_dir, SaveCheckPoint, ImageSize, number_of_test_samples, labels_in_dir = SetupAll(base_path, CheckPointPath,True)
#Model Checkpoint
checkpoint = "/home/gokul/CMSC733/hgokul_p1/Phase2/Checkpoints/supervised/weights-47-15.19.hdf5"

batch_size = 64
num_steps = int(number_of_test_samples / batch_size)

# loss = tf.sqrt(tf.reduce_sum((tf.squared_difference(H4pt,LabelPH))))
# load model
model = load_model(checkpoint, custom_objects={'L2_loss': L2_Loss})


#use optimizer Stochastic Gradient Methond with a Learning Rate of 0.005 and momentum of 0.9
# sgd = optimizers.SGD(lr=0.005, momentum=0.9)

# #compile model
# model.compile(loss=L2_loss,\
#         optimizer=sgd, metrics=['mae'])

generator = loadDataBatches_gen(base_path, files_in_dir, labels_in_dir, batch_size, True)
# Test
score = model.evaluate_generator(generator,steps=2)

print('Metrics', model.metrics_names)
print('Test score:', score)
# Out:
# Metrics ['loss', 'mean_absolute_error']
# Test score: [51.421194076538086, 15.58031177520752]

# %%
i = 2

pathA = "/home/gokul/CMSC733/hgokul_p1/Phase2/Data/Train_synthetic/PA/" + str(i) + ".jpg"
pathB = "/home/gokul/CMSC733/hgokul_p1/Phase2/Data/Train_synthetic/PB/" + str(i) + ".jpg"

patchA = cv2.imread(pathA)[:,:,0]
patchB = cv2.imread(pathB)[:,:,0]

patchA = cv2.normalize(patchA.astype(np.float32), None, 0.0, 1.0, cv2.NORM_MINMAX)
patchB = cv2.normalize(patchB.astype(np.float32), None, 0.0, 1.0, cv2.NORM_MINMAX)

# %%
testPatch1 = np.dstack((patchA, patchB))

# %%
testPatch2 = np.dstack((patchA, patchB))

# %%
testPatch = np.array([testPatch1,testPatch2])

# %%
testPatch.shape
# Out:
# (2, 128, 128, 2)

# %%
all_labels = pd.read_csv("/home/gokul/CMSC733/hgokul_p1/Phase2/Data/Train_synthetic/H4.csv")

label = np.array([all_labels.iloc[0],all_labels.iloc[1]])
print(label)
# Out:
# [[ -6.  -4.  -4.  29.  12. -22. -17.  18.]
#  [  2.  22. -29.   9. -25.  -8.  25.  -8.]]

# %%
y_ = model.predict(testPatch)
print(y_-label)
# Out:
# [[  8.6096282   10.50418949   2.34299016 -33.24000406  -1.69576263
#    28.06253624  24.25899553 -16.65936613]
#  [  0.56260967 -15.69626808  27.44535768 -13.14529324  35.25891685
#    14.45791054 -17.63935804   9.42253208]]

# %%
# Out:
# Batch Count:  0
# Batch Count:  1
# Batch Count:  2
# Batch Count:  3
# Batch Count:  4
# Batch Count:  5
# Batch Count:  6
# Batch Count:  7
# Batch Count:  8
# Batch Count:  9
# Batch Count:  10
# Batch Count:  11
# Batch Count:  12
# Test score: [50.58407974243164, 15.341800212860107]

# %%
len(files_in_dir)
# Out:
# 999
